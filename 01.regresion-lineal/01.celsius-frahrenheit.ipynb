# %% [markdown]
# # Importar la librería

# %%
import pandas as pd

# %% [markdown]
# # Leer los datos del dataset

# %%
data = pd.read_csv('dataset.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   celsius      7 non-null      int64
#  1   frahrenheit  7 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 244.0 bytes

# %%
data.head()
# Out:
#    celsius  frahrenheit
# 0      -40        -40.0
# 1      -10         14.0
# 2        0         32.0
# 3        8         46.4
# 4       15         59.0

# %% [markdown]
# # Gráfica con seaboar

# %%
import seaborn as sb
sb.scatterplot(x='celsius', y='frahrenheit', data=data,
               hue='frahrenheit', size='frahrenheit', sizes=(20, 200), alpha=0.5)
# Out:
# <Axes: xlabel='celsius', ylabel='frahrenheit'>

# %% [markdown]
# > La gráfica que nos ofrece es una traza líneal, perfectamente para aplicar un modelo basado en regresión líneal

# %% [markdown]
# # Preparar los datos

# %%
# Características (X) y etiquetas (y)
X = data['celsius']
y = data['frahrenheit']

# %%
y
# Out:
# 0    -40.0
# 1     14.0
# 2     32.0
# 3     46.4
# 4     59.0
# 5     71.6
# 6    100.4
# Name: frahrenheit, dtype: float64

# %%
X.values
# Transformando a un array
# [-40, -10, 0, 8, 15, 22, 38]
# [[-40], [-10], [0], [8], [15], [22], [38]]
X_procesada = X.values.reshape(-1, 1)
y_procesada = y.values.reshape(-1, 1)

# %% [markdown]
# # Crear nuestro primer modelo

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()# aplicar en modelo de regresión lineal de sklearn

# %%
# Entrenando del modelo
model.fit(X_procesada, y_procesada)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicción

# %%
model.predict([[5]])
# Out:
# array([[41.]])

# %%
celsius = 7900
prediccion = model.predict([[celsius]])
print(f'La temperatura de {celsius}°C es equivalente a {prediccion[0][0]}°F')
# Out:
# La temperatura de 7900°C es equivalente a 14252.0°F

# %%
model.score(X_procesada, y_procesada)
# Out:
# 1.0
